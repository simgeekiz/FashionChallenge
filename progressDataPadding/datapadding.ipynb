# %%
from PIL import Image, ImageOps

# %% [markdown]
# ### One Image

# %%
desired_size = 600
im_pth = "images/52157ddd1c238845733632b9-large.jpg"
im = Image.open(im_pth)
old_size = im.size  # old_size[0] is in (width, height) format
ratio = float(desired_size)/max(old_size)
new_size = tuple([int(x*ratio) for x in old_size])
im = im.resize(new_size, Image.ANTIALIAS)
im.size
# Out:
# (450, 600)

# %%
new_im = Image.new("RGB", (desired_size, desired_size), color=(0,0,255))
new_im.paste(im, ((desired_size-new_size[0])//2,
                    (desired_size-new_size[1])//2))

# %%
new_im
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x2B8EECE34748>

# %% [markdown]
# ## Estimating the max size of images

# %%
import os
path, dirs, files = next(os.walk("images"))
file_count = len(files)

# %%
image_sizes = []
for i in files:
    im_pth = "images/" + i
    im = Image.open(im_pth)
    image_sizes.append(im.size)

# %%
# image_sizes

# %%
desired_size = [max(image_sizes,key=lambda item:item[1])[1], max(image_sizes,key=lambda item:item[0])[0]]
desired_size
# Out:
# [600, 600]

# %% [markdown]
# ## Add Padding

# %%
padded_images = []

# %%
desired_size = 600

# %%
index=0
for i in files:
    im_pth = "images/" + i
    im = Image.open(im_pth)
    old_size = im.size
    ratio = float(desired_size)/max(old_size)
    new_size = tuple([int(x*ratio) for x in old_size])
    im = im.resize(new_size, Image.ANTIALIAS)
    new_ima = Image.new("RGB", (desired_size,desired_size), color=(255,255,255))
    new_ima.paste(im, ((desired_size-new_size[0])//2,
                    (desired_size-new_size[1])//2))
    padded_images.append(new_ima)
    index = index + 1

# %%
number = 4
for number in range(len(files)):
    #print(image_sizes[number])
   # print(padded_images[number].size)
    padded_images[number]
